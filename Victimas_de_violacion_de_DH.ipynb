# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel01-prog/Ejercicio_1/blob/main/Victimas_de_violacion_de_DH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estadistica Descriptiva

# %% [markdown]
# # Nueva sección

# %% [markdown]
# Cargar las librerias

# %%
# %config IPCompleter.greedy=True
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %% [markdown]
# Cargar base de datos

# %%
from google.colab import files

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/My drive/Victimas de violacion de DH.xlsx")
df.shape
# Out:
# (64, 8)

# %%
df.head(67)
# Out:
#                  Entidad federativa  Periodo     Salud  Sector de vivienda  \
# 0                    Aguascalientes   2016.0  1.449275                12.0
# 1                   Baja California   2016.0  0.000000                 0.0
# 2               Baja California Sur   2016.0  1.488266                52.0
# 3                          Campeche   2016.0  7.496902               121.0
# 4              Coahuila de Zaragoza   2016.0  8.813559               312.0
# ..                              ...      ...       ...                 ...
# 59                       Tamaulipas   2017.0  0.000000                 0.0
# 60                         Tlaxcala   2017.0  3.492063                22.0
# 61  Veracruz de Ignacio de la Llave   2017.0  2.755102                54.0
# 62                          Yucatán   2017.0  1.116751                22.0
# 63                        Zacatecas   2017.0  0.000000                 0.0
#
# ...

# %%
df.tail()
# Out:
#                  Entidad federativa  Periodo     Salud  Sector de vivienda  \
# 59                       Tamaulipas   2017.0  0.000000                 0.0
# 60                         Tlaxcala   2017.0  3.492063                22.0
# 61  Veracruz de Ignacio de la Llave   2017.0  2.755102                54.0
# 62                          Yucatán   2017.0  1.116751                22.0
# 63                        Zacatecas   2017.0  0.000000                 0.0
#
#     Amenazas para declinar noticias al Estado.  Poblacion        Media  \
# 59                                         0.0   3511463.0     #DIV/0!
# 60                                       630.0   1265055.0  218.497355
# 61                                      1960.0   7998824.0  672.251701
# 62                                      1970.0   2097203.0   664.37225
# 63                                      2257.0   1566089.0      2257.0
#
#             Tasa
# 59       #DIV/0!
# 60   578979550.1
# 61  1189855525.0
# ...

# %%
df.sample()
# Out:
#      Entidad federativa  Periodo      Salud  Sector de vivienda  \
# 47  Michoacán de Ocampo   2017.0  11.447811                68.0
#
#     Amenazas para declinar noticias al Estado.  Poblacion        Media  \
# 47                                       594.0   4571000.0  224.482604
#
#             Tasa
# 47  2036237963.0

# %%
df.describe()
# Out:
#            Periodo      Salud  Sector de vivienda  \
# count    64.000000  64.000000           64.000000
# mean   2016.500000   3.428463          293.859375
# std       0.503953   2.945101         1052.946250
# min    2016.000000   0.000000            0.000000
# 25%    2016.000000   1.478518           19.500000
# 50%    2016.500000   3.163855           58.000000
# 75%    2017.000000   4.632255          161.500000
# max    2017.000000  15.283922         7566.000000
#
#        Amenazas para declinar noticias al Estado.    Poblacion
# count                                   64.000000  6.400000e+01
# mean                                  4901.390625  3.749690e+06
# std                                   8455.087124  3.169874e+06
# min                                      0.000000  7.136120e+05
# 25%                                   1017.000000  1.704616e+06
# 50%                                   2210.000000  2.916753e+06
# 75%                                   5211.750000  4.685442e+06
# ...

# %%
df.describe(include='all')
# Out:
#        Entidad federativa      Periodo      Salud  Sector de vivienda  \
# count                  64    64.000000  64.000000           64.000000
# unique                 32          NaN        NaN                 NaN
# top        Aguascalientes          NaN        NaN                 NaN
# freq                    2          NaN        NaN                 NaN
# mean                  NaN  2016.500000   3.428463          293.859375
# std                   NaN     0.503953   2.945101         1052.946250
# min                   NaN  2016.000000   0.000000            0.000000
# 25%                   NaN  2016.000000   1.478518           19.500000
# 50%                   NaN  2016.500000   3.163855           58.000000
# 75%                   NaN  2017.000000   4.632255          161.500000
# max                   NaN  2017.000000  15.283922         7566.000000
#
#         Amenazas para declinar noticias al Estado.    Poblacion     Media  \
# ...

# %% [markdown]
# 1. Sacar MTC/ Columna en especifico.

# %%
df['Poblacion '].describe()
# Out:
# count    6.400000e+01
# mean     3.749690e+06
# std      3.169874e+06
# min      7.136120e+05
# 25%      1.704616e+06
# 50%      2.916753e+06
# 75%      4.685442e+06
# max      1.667210e+07
# Name: Poblacion , dtype: float64

# %%
df['Entidad federativa'].describe()
# Out:
# count                 64
# unique                32
# top       Aguascalientes
# freq                   2
# Name: Entidad federativa, dtype: object

# %%
df['Poblacion '].unique()
# Out:
# array([ 1273404.,  3443792.,   745601.,   897291.,  2932657.,   713612.,
#         5200849.,  3681473.,  8870622.,  1750791.,  5780123.,  3551527.,
#         2850714.,  7857979., 16672099.,  4571000.,  1902329.,  1206119.,
#         5028766.,  3991911.,  6144886.,  1980225.,  1539101.,  2733708.,
#         2965379.,  2900849.,  2364632.,  3511463.,  1265055.,  7998824.,
#         2097203.,  1566089.])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df.describe()
# Out:
#            Periodo      Salud  Sector de vivienda  \
# count    64.000000  64.000000           64.000000
# mean   2016.500000   3.428463          293.859375
# std       0.503953   2.945101         1052.946250
# min    2016.000000   0.000000            0.000000
# 25%    2016.000000   1.478518           19.500000
# 50%    2016.500000   3.163855           58.000000
# 75%    2017.000000   4.632255          161.500000
# max    2017.000000  15.283922         7566.000000
#
#        Amenazas para declinar noticias al Estado.    Poblacion
# count                                   64.000000  6.400000e+01
# mean                                  4901.390625  3.749690e+06
# std                                   8455.087124  3.169874e+06
# min                                      0.000000  7.136120e+05
# 25%                                   1017.000000  1.704616e+06
# 50%                                   2210.000000  2.916753e+06
# 75%                                   5211.750000  4.685442e+06
# ...

# %%
#Indicame el máximo
df['Poblacion ']. max()
# Out:
# 16672099.0

# %%
#Indicame la media
df['Poblacion '].mean()
# Out:
# 3749689.78125

# %%
#Indicame un análisis de frecuencias
#Lo que vemos son los datos más repetidos "Moda"
df['Poblacion '].value_counts()
# Out:
# 1273404.0     2
# 3443792.0     2
# 2097203.0     2
# 7998824.0     2
# 1265055.0     2
# 3511463.0     2
# 2364632.0     2
# 2900849.0     2
# 2965379.0     2
# 2733708.0     2
# 1539101.0     2
# 1980225.0     2
# 6144886.0     2
# 3991911.0     2
# 5028766.0     2
# 1206119.0     2
# 1902329.0     2
# 4571000.0     2
# 16672099.0    2
# 7857979.0     2
# 2850714.0     2
# 3551527.0     2
# 5780123.0     2
# 1750791.0     2
# 8870622.0     2
# 3681473.0     2
# 5200849.0     2
# 713612.0      2
# 2932657.0     2
# 897291.0      2
# 745601.0      2
# 1566089.0     2
# Name: Poblacion , dtype: int64

# %%
#Diagrama de lineas
df.plot.scatter(x= 'Salud' ,y='Poblacion ')

# %%
#realizar histograma
df.plot.hist()

# %%
df['Sector de vivienda'].plot.hist()

# %%
df.plot.box()

# %%
#Diagramas de caja //Mayor dispersión entre el cuartil de incidentes.
df.groupby('Entidad federativa').boxplot(figsize=(15,15),rot=45)
# Out:
# Aguascalientes                          AxesSubplot(0.1,0.792857;0.114286x0.107143)
# Baja California                    AxesSubplot(0.237143,0.792857;0.114286x0.107143)
# Baja California Sur                AxesSubplot(0.374286,0.792857;0.114286x0.107143)
# Campeche                           AxesSubplot(0.511429,0.792857;0.114286x0.107143)
# Chiapas                            AxesSubplot(0.648571,0.792857;0.114286x0.107143)
# Chihuahua                          AxesSubplot(0.785714,0.792857;0.114286x0.107143)
# Ciudad de México                        AxesSubplot(0.1,0.664286;0.114286x0.107143)
# Coahuila de Zaragoza               AxesSubplot(0.237143,0.664286;0.114286x0.107143)
# Colima                             AxesSubplot(0.374286,0.664286;0.114286x0.107143)
# Durango                            AxesSubplot(0.511429,0.664286;0.114286x0.107143)
# Guanajuato                         AxesSubplot(0.648571,0.664286;0.114286x0.107143)
# ...

# %%
tabla = pd.pivot_table(df,values = 'Tasa', index= 'Poblacion ', aggfunc= np.mean)
tabla
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py:979: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   result = op.agg()
# Empty DataFrame
# Columns: []
# Index: [713612.0, 745601.0, 897291.0, 1206119.0, 1265055.0, 1273404.0, 1539101.0, 1566089.0, 1750791.0, 1902329.0, 1980225.0, 2097203.0, 2364632.0, 2733708.0, 2850714.0, 2900849.0, 2932657.0, 2965379.0, 3443792.0, 3511463.0, 3551527.0, 3681473.0, 3991911.0, 4571000.0, 5028766.0, 5200849.0, 5780123.0, 6144886.0, 7857979.0, 7998824.0, 8870622.0, 16672099.0]
